# %% [markdown]
# # Session 1 - 선형 모델 구현하기
#
# 지금부터 학생들이 공부한 시간에 따라 산출된 시험 점수를 담은 데이터셋을 통해 어떠한 상관관계가 있는지 선형 모델을 이용하여 예측할 것이다. 이를 위해서 아래와 같은 Python Library를 사용할 것이다.
#
# - Pandas : 데이터셋 관리를 위해
# - Matplotlib : 그래프 시각화를 위해
# - Scikit-Learn : 선형 모델 예측 신경망 가져오기

# %%
import pandas as pd
from sklearn import linear_model as lm
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# ## 데이터셋 불러오기

# %%
dataset = pd.read_csv('student_score.csv')
display(dataset)
# Out:
#     Student  Time  Score
# 0         1   2.4      6
# 1         2   4.5      7
# 2         3   6.1     14
# 3         4  20.8     20
# 4         5   3.1      8
# 5         6   1.0      3
# 6         7   1.2      1
# 7         8   7.1    146
# 8         9   6.5      7
# 9        10  14.1      1
# 10       11   2.6     18
# 11       12   7.3     18
# 12       13   5.6      2
# 13       14   3.4     30
# 14       15   2.3     16
# 15       16   9.8     10
# 16       17   4.7      0
# 17       18  10.2     61
# 18       19   5.9     14
# 19       20  13.5    129
# 20       21  16.0     51
# 21       22  26.0      4
# 22       23  21.0    650
# 23       24   8.5    192
# 24       25  18.5     32
# 25       26  18.5      3
# 26       27  11.0     92
# 27       28   6.0     74
# 28       29  13.5    430
# 29       30  18.5      5
# ..      ...   ...    ...
# 70       71  26.0     47
# 71       72   1.0      3
# 72       73   3.5     36
# 73       74   8.5    212
# 74       75  26.0     35
# 75       76  18.5     34
# 76       77  23.5    285
# 77       78   3.5     49
# 78       79   6.0     23
# 79       80  18.5      6
# 80       81  13.5     78
# 81       82  21.0     65
# 82       83  13.5    130
# 83       84  11.0    136
# 84       85   8.5     61
# 85       86   8.5     22
# 86       87  11.0    303
# 87       88  11.0     78
# 88       89   8.5     20
# 89       90  23.5      1
# 90       91  21.0     10
# 91       92  13.5    137
# 92       93  16.0     34
# 93       94  23.5    103
# 94       95  26.0      3
# 95       96  21.0     53
# 96       97   6.0      2
# 97       98  13.5    251
# 98       99  18.5    106
# 99      100  24.2     14
#
# [100 rows x 3 columns]

# %% [markdown]
# ## 선형 모델을 훈련 데이터로 학습하기

# %%
x = dataset[['Time']]
y = dataset[['Score']]

linear_model = lm.LinearRegression()
linear_model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ## 학습 결과 시각화

# %%
plt.scatter(x, y)
plt.plot(x, linear_model.predict(x))
plt.title("The Correlation between Learning Times and Results")
plt.xlabel("Learning Time(s)")
plt.ylabel("Score")
plt.axis((-5, 30, -150, 200))
plt.show()

# %% [markdown]
# 이와 같이 (사실 엑셀로 만든 무작위 데이터셋...)학생들의 학습 결과를 통한 상관관계를 비례함을 알 수 있다.
